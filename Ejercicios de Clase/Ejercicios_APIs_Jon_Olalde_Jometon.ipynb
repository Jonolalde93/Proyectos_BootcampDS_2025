# %%
import requests
import pandas as pd

# %%
url_incidents = "https://api.euskadi.eus/traffic/v1.0/incidences"

response = requests.get(url_incidents)
data_incidents = response.json()
df_incidents = pd.DataFrame(data_incidents)
df_incidents.head(40)
# Out:
#     totalItems  totalPages  currentPage  \
# 0       291072       14554            1
# 1       291072       14554            1
# 2       291072       14554            1
# 3       291072       14554            1
# 4       291072       14554            1
# 5       291072       14554            1
# 6       291072       14554            1
# 7       291072       14554            1
# 8       291072       14554            1
# 9       291072       14554            1
# 10      291072       14554            1
# 11      291072       14554            1
# 12      291072       14554            1
# 13      291072       14554            1
# 14      291072       14554            1
# 15      291072       14554            1
# 16      291072       14554            1
# 17      291072       14554            1
# 18      291072       14554            1
# 19      291072       14554            1
#
#                                            incidences
# 0   {'incidenceId': '287346', 'sourceId': '1', 'in...
# ...

# %%
url_cameras = "https://api.euskadi.eus/traffic/v1.0/cameras"

response = requests.get(url_cameras)
data_cameras = response.json()
print("Claves en cameras:", data_cameras.keys())


    
df_cameras = pd.DataFrame(data_cameras.get('cameras', []))
print("Cámaras:", df_cameras.shape)
print(df_cameras.columns) 
df_cameras.head(40)
# Out:
# Claves en cameras: dict_keys(['totalItems', 'totalPages', 'currentPage', 'cameras'])
# Cámaras: (20, 9)
# Index(['cameraId', 'sourceId', 'cameraName', 'latitude', 'longitude', 'road',
#        'kilometer', 'address', 'urlImage'],
#       dtype='object')
#    cameraId sourceId                                   cameraName    latitude  \
# 0        75        2                   CCTV 232 - Cámara DOMO 232  4792953.64
# 1        76        2                                     DOMO 233  4794032.11
# 2        77        2        CCTV 300 - Cámara DOMO nudo Kukularra  4794665.86
# 3        78        2               CCTV 301 - Curvas de Kukularra  4795334.63
# 4        79        2                          CCTV 302 - Avanzada  4795927.48
# 5        80        2  CCTV 303 - Entrada Túnel Leioa (dir. Getxo)  4796823.02
# 6        81        2      CCTV 304 - DOMO La Avanzada túnel largo  4796989.22
# 7        82        2  CCTV 305 - DOMO La Avanzada túnel del medio  4797162.77
# ...

# %%
import pyproj
import pandas as pd
import folium
from folium.plugins import MarkerCluster

# Folium necesita coordenadas decimales al parecer y las que vienen en el dataset son UTM por lo que he tenido que buscar la manera de convertirlo
transformer = pyproj.Transformer.from_crs("EPSG:25830", "EPSG:4326", always_xy=True)

def convertir_utm_a_latlon(x, y):
    lon, lat = transformer.transform(x, y)
    return lat, lon
df_cameras[['lat', 'lon']] = df_cameras.apply(
    lambda row: pd.Series(convertir_utm_a_latlon(row['longitude'], row['latitude'])),
    axis=1
)

mapa_camaras = folium.Map(location=[43.2627, -2.93499], zoom_start=12) # La ubicacion que he seleccionado es Bilbao en este caso ya que de ahi son los elementos del dataset
marker_cluster = MarkerCluster().add_to(mapa_camaras)

for _, row in df_cameras.iterrows():
    if pd.notnull(row['lat']) and pd.notnull(row['lon']):
        popup_html = f"<b>{row['cameraName']}</b>"
        if pd.notnull(row['urlImage']):
            popup_html += f"<br><img src='{row['urlImage']}' width='200'>"
        
        folium.Marker(
            location=[row['lat'], row['lon']],
            popup=popup_html,
            icon=folium.Icon(color='blue', icon='camera', prefix='fa')
        ).add_to(marker_cluster)

mapa_camaras
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
year = 2025
month = 5
day = 21

url_flow = f"https://api.euskadi.eus/traffic/v1.0/flows/byDate/{year}/{month}/{day}"

response = requests.get(url_flow)
data_flow = response.json()
print("Claves en data_flow:", data_flow.keys()) 

flows_list = data_flow.get('flows', [])
df_flow = pd.DataFrame(flows_list)
df_flow.head(40)
# Out:
# Claves en data_flow: dict_keys(['totalItems', 'totalPages', 'currentPage', 'flows'])
#    meterId sourceId   meterDate       timeRank totalVehicles speedIntervals  \
# 0       -1        6  2025-05-21  11:45 - 12:00             6             []
# 1       -1        6  2025-05-21  06:45 - 07:00             3             []
# 2       -1        6  2025-05-21  06:15 - 06:30             1             []
# 3       -1        6  2025-05-21  04:30 - 04:45             0             []
# 4       -1        6  2025-05-21  00:45 - 01:00             0             []
# 5       -1        6  2025-05-21  10:45 - 11:00             6             []
# 6       -1        6  2025-05-21  01:15 - 01:30             0             []
# 7       -1        6  2025-05-21  10:15 - 10:30             8             []
# 8       -1        6  2025-05-21  11:15 - 11:30             7             []
# 9       -1        6  2025-05-21  03:45 - 04:00             0             []
# ...

# %%
year = 2025
month = 5
day = 21

url_incidences = f"https://api.euskadi.eus/traffic/v1.0/incidences/byDate/{year}/{month}/{day}"

response = requests.get(url_incidences)
data_incidences = response.json()
print("Claves en incidencias:", data_incidences.keys())
incidences_list = data_incidences.get('incidences', [])
df_incidences = pd.DataFrame(incidences_list)
df_incidences.head(40)
# Out:
# Claves en incidencias: dict_keys(['totalItems', 'totalPages', 'currentPage', 'incidences'])
#    incidenceId sourceId incidenceType autonomousRegion  province  \
# 0         1206        7          OTRO          Euskadi  Gipuzkoa
# 1         1205        7          OBRA          Euskadi  Gipuzkoa
# 2         1196        7          OBRA          Euskadi  Gipuzkoa
# 3         1194        7          OBRA          Euskadi  Gipuzkoa
# 4         1181        7          OBRA          Euskadi  Gipuzkoa
# 5         1153        7          OBRA          Euskadi  Gipuzkoa
# 6         1125        7          OBRA          Euskadi  Gipuzkoa
# 7         1124        7          OBRA          Euskadi  Gipuzkoa
# 8         1102        7          OTRO          Euskadi  Gipuzkoa
# 9         1098        7          OTRO          Euskadi  Gipuzkoa
# 10         996        7          OTRO          Euskadi  Gipuzkoa
#
#                                                 cause  \
# ...

# %%
print(df_incidences.columns)
# Out:
# Index(['incidenceId', 'sourceId', 'incidenceType', 'autonomousRegion',
#        'province', 'cause', 'cityTown', 'startDate', 'endDate', 'pkStart',
#        'pkEnd', 'direction', 'incidenceName', 'latitude', 'longitude'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df_incidences = df_incidences[df_incidences['incidenceType'].notna()]
plt.figure(figsize=(12, 6))
sns.countplot(
    data=df_incidences,
    y='incidenceType',
    order=df_incidences['incidenceType'].value_counts().index,
    palette="Set2"
)

plt.title("Número de incidencias por tipo (21 de mayo de 2025)")
plt.xlabel("Número de incidencia")
print(df_incidences['incidenceType'].value_counts())
# Out:
# incidenceType
# OBRA    7
# OTRO    4
# Name: count, dtype: int64
# C:\Users\Jon\AppData\Local\Temp\ipykernel_15120\139403784.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(

# %%
mapa_donosti = folium.Map(location=[43.3214, -1.9855], zoom_start=13)
marker_cluster = MarkerCluster().add_to(mapa_donosti)
colores = {
    tipo: color for tipo, color in zip(
        df_incidences['incidenceType'].unique(),
        ['red', 'blue', 'green', 'purple', 'orange', 'darkred', 'lightblue']
    )
}

for _, row in df_incidences.iterrows():
    tipo = row['incidenceType']
    popup_text = f"<b>{tipo}</b><br>{row['incidenceName']}<br>{row['cityTown']}"
    folium.CircleMarker(
        location=[row['latitude'], row['longitude']],
        radius=6,
        color=colores.get(tipo, 'gray'),
        fill=True,
        fill_opacity=0.8,
        popup=popup_text
    ).add_to(marker_cluster)
mapa_donosti
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...
